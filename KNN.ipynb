# %% [markdown]
# <a href="https://colab.research.google.com/github/MariamKhan98/mariamkhan98/blob/main/KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.neighbors import NearestNeighbors
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv('https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv')

# %%
df = data[['sepal_length', 'sepal_width']]

# %%
plt.scatter(df['sepal_length'], df['sepal_width'])

# %%
X = df.values
nbrs = NearestNeighbors(n_neighbors=3, algorithm='ball_tree').fit(X)

# %%
nbrs.fit(X)
# Out:
# NearestNeighbors(algorithm='ball_tree', n_neighbors=3)

# %%
NearestNeighbors(n_neighbors=3)
# Out:
# NearestNeighbors(n_neighbors=3)

# %%
distances, indices = nbrs.kneighbors(X)
plt.plot(distances.mean(axis=1))

# %%
outlier_index = np.where(distances.mean(axis=1) > 0.15)
outlier_index
# Out:
# (array([ 14,  15,  18,  22,  32,  33,  41,  59,  60, 108, 109, 117, 118,
#         131]),)

# %%
outlier_values = df.iloc[outlier_index]
outlier_values
# Out:
#      sepal_length  sepal_width
# 14            5.8          4.0
# 15            5.7          4.4
# 18            5.7          3.8
# 22            4.6          3.6
# 32            5.2          4.1
# 33            5.5          4.2
# 41            4.5          2.3
# 59            5.2          2.7
# 60            5.0          2.0
# 108           6.7          2.5
# 109           7.2          3.6
# 117           7.7          3.8
# 118           7.7          2.6
# 131           7.9          3.8

# %%
plt.scatter(df['sepal_length'], df['sepal_width'], color = 'b', s=65)
plt.scatter(outlier_values['sepal_length'], outlier_values['sepal_width'], color='red')

# %%
#this is how we find anomalies using KNN
